# %% [markdown]
# <a href="https://colab.research.google.com/github/ylcoder/random-walk/blob/main/poly_market_api_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json

# --- Configuration ---
# Replace with your actual Polymarket API Key
API_KEY = 'YOUR_POLYMARKET_API_KEY'
# Replace with the actual Polymarket API base URL for data
BASE_URL = 'https://gamma-api.polymarket.com/' # This is a hypothetical URL

# --- Function to fetch popular contract IDs ---
def get_popular_contract_ids(limit=5):
    headers = {
        # 'Authorization': f'Bearer {API_KEY}',
        # 'Content-Type': 'application/json'
    }
    # Hypothetical endpoint for popular markets. Adjust according to Polymarket API docs.
    # It's assumed this endpoint returns a list of market objects, each with an 'id'.
    endpoint = f'{BASE_URL}markets?sort=popular&limit={limit}'

    try:
        print(f"Attempting to fetch popular contract IDs from: {endpoint}")
        response = requests.get(endpoint, headers=headers)
        response.raise_for_status()  # Raise an HTTPError for bad responses (4xx or 5xx)
        data = response.json()

        # Assuming the response is a list of market objects and each has an 'id' field
        contract_ids = [market['id'] for market in data if 'id' in market]
        print(f"Fetched {len(contract_ids)} popular contract IDs.")
        return contract_ids
    except requests.exceptions.HTTPError as http_err:
        print(f"HTTP error occurred fetching popular contracts: {http_err}")
        print(f"Response content: {response.text}")
    except requests.exceptions.ConnectionError as conn_err:
        print(f"Connection error occurred: {conn_err}")
    except requests.exceptions.Timeout as timeout_err:
        print(f"Timeout error occurred: {timeout_err}")
    except requests.exceptions.RequestException as req_err:
        print(f"An error occurred: {req_err}")
    return []

# --- Function to fetch data for a single contract ---
def get_contract_data(contract_id):
    headers = {
        # 'Authorization': f'Bearer {API_KEY}',
        # 'Content-Type': 'application/json'
    }
    # Adjust the endpoint path based on actual Polymarket API documentation
    endpoint = f'{BASE_URL}markets/{contract_id}' # Hypothetical endpoint

    try:
        response = requests.get(endpoint, headers=headers)
        response.raise_for_status()  # Raise an HTTPError for bad responses (4xx or 5xx)
        return response.json()
    except requests.exceptions.HTTPError as http_err:
        print(f"HTTP error occurred: {http_err} for contract {contract_id}")
        print(f"Response content: {response.text}")
    except requests.exceptions.ConnectionError as conn_err:
        print(f"Connection error occurred: {conn_err}")
    except requests.exceptions.Timeout as timeout_err:
        print(f"Timeout error occurred: {timeout_err}")
    except requests.exceptions.RequestException as req_err:
        print(f"An error occurred: {req_err}")
    return None

# --- Main execution ---
all_contracts_data = []
print("Fetching data for Polymarket contracts...")

# Get popular contract IDs dynamically
CONTRACT_IDS = get_popular_contract_ids(limit=5)

if not CONTRACT_IDS:
    print("Could not fetch popular contract IDs. Please check API key, base URL, and endpoint for popular markets.")
else:
    for i, contract_id in enumerate(CONTRACT_IDS):
        print(f"\nFetching data for contract {i+1}/{len(CONTRACT_IDS)}: {contract_id}")
        data = get_contract_data(contract_id)
        if data:
            all_contracts_data.append(data)
            print(f"Successfully fetched data for {contract_id}")
            # Optional: print a snippet of the data
            # print(json.dumps(data, indent=2))
        else:
            print(f"Failed to fetch data for {contract_id}")

print("\n--- Download Complete ---")
print(f"Total contracts data fetched: {len(all_contracts_data)}")

# You can now process or save 'all_contracts_data'
# Example: print the first fetched contract's data
if all_contracts_data:
    print("\nFirst contract data example:")
    print(json.dumps(all_contracts_data[0], indent=2))
# Out:
# Fetching data for Polymarket contracts...
# Attempting to fetch popular contract IDs from: https://gamma-api.polymarket.com/markets?sort=popular&limit=5
# Fetched 5 popular contract IDs.
#
# Fetching data for contract 1/5: 12
# Successfully fetched data for 12
#
# Fetching data for contract 2/5: 17
# Successfully fetched data for 17
#
# Fetching data for contract 3/5: 18
# Successfully fetched data for 18
#
# Fetching data for contract 4/5: 19
# Successfully fetched data for 19
#
# Fetching data for contract 5/5: 20
# Successfully fetched data for 20
#
# --- Download Complete ---
# Total contracts data fetched: 5
#
# First contract data example:
# {
#   "id": "12",
#   "question": "Will Joe Biden get Coronavirus before the election?",
#   "conditionId": "0xe3b423dfad8c22ff75c9899c4e8176f628cf4ad4caa00481764d320e7415f7a9",
#   "slug": "will-joe-biden-get-coronavirus-before-the-election",
#   "twitterCardImage": "https://polymarket-static.s3.us-east-2.amazonaws.com/polymarket-twitter-card.png",
#   "endDate": "2020-11-04T00:00:00Z",
#   "category": "US-current-affairs",
#   "liquidity": "0",
#   "image": "https://polymarket-upload.s3.us-east-2.amazonaws.com/will-joe-biden-get-coronavirus-before-the-election-5a3d4c3b-0a73-419e-a686-be034d2c73ac.png",
#   "icon": "https://polymarket-upload.s3.us-east-2.amazonaws.com/will-joe-biden-get-coronavirus-before-the-election-5a3d4c3b-0a73-419e-a686-be034d2c73ac.png",
#   "description": "This is a market on if presidential candidate Joe Biden will test positive for COVID-19 before November 3rd, 2020. This will be defined as Joe publicly announcing - via any medium, including social media - that he has tested positive for COVID-19, or some variation of that statement. If it is in reference to antibodies, or he doesn\u2019t publicly acknowledge it, the market will resolve to No.\nIn the event of ambiguity in terms of the market outcome, the market will be resolved at the sole discretion of the Markets Integrity Committee (MIC).",
#   "outcomes": "[\"Yes\", \"No\"]",
#   "outcomePrices": "[\"0\", \"0\"]",
#   "volume": "32257.445115",
#   "active": true,
#   "marketType": "normal",
#   "closed": true,
#   "marketMakerAddress": "0x8BD6C3D7a57D650A1870dd338234f90051fe9918",
#   "updatedBy": 9,
#   "createdAt": "2020-10-02T16:10:01.467Z",
#   "updatedAt": "2024-04-23T00:49:51.620233Z",
#   "closedTime": "2020-11-02 16:31:01+00",
#   "mailchimpTag": "3917403",
#   "archived": false,
#   "restricted": false,
#   "volumeNum": 32257.45,
#   "liquidityNum": 0,
#   "endDateIso": "2020-11-04",
#   "hasReviewedDates": true,
#   "readyForCron": true,
#   "volume24hr": 0,
#   "volume1wk": 0,
#   "volume1mo": 0,
#   "volume1yr": 0,
#   "clobTokenIds": "[\"53135072462907880191400140706440867753044989936304433583131786753949599718775\", \"60869871469376321574904667328762911501870754872924453995477779862968218702336\"]",
#   "fpmmLive": true,
#   "volume1wkAmm": 0,
#   "volume1moAmm": 0,
#   "volume1yrAmm": 0,
#   "volume1wkClob": 0,
#   "volume1moClob": 0,
#   "volume1yrClob": 0,
#   "creator": "",
#   "ready": false,
#   "funded": false,
#   "cyom": false,
#   "competitive": 0,
#   "pagerDutyNotificationEnabled": false,
#   "approved": true,
#   "rewardsMinSize": 0,
#   "rewardsMaxSpread": 0,
#   "spread": 1,
#   "oneDayPriceChange": 0,
#   "oneHourPriceChange": 0,
#   "oneWeekPriceChange": 0,
#   "oneMonthPriceChange": 0,
#   "oneYearPriceChange": 0,
#   "lastTradePrice": 0,
#   "bestBid": 0,
#   "bestAsk": 1,
#   "clearBookOnStart": true,
#   "manualActivation": false,
#   "negRiskOther": false,
#   "umaResolutionStatuses": "[]",
#   "pendingDeployment": false,
#   "deploying": false,
#   "rfqEnabled": false,
#   "holdingRewardsEnabled": false,
#   "feesEnabled": false,
#   "requiresTranslation": false,
#   "feeType": null
# }
